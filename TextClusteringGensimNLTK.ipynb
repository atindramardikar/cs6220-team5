# %%
# Please install gensim & NLTK packages beforehand
# https://pypi.python.org/pypi/gensim
# http://www.nltk.org/install.html

import pandas as pd
import numpy as np
import gensim

# This program takes too long to execute :( 
# Gensim constructs a vector for a document
# which takes a long time since it creates a 'model'
# which is trained on a corpus

# %%
# read the dataset
print("Reading data.csv")
data = pd.read_csv('Consumer_Complaints.csv')
print("number of records - ", len(data))
print(data.columns)
# Out:
# Reading data.csv
# number of records -  891360
# Index(['Date received', 'Product', 'Sub-product', 'Issue', 'Sub-issue',
#        'Consumer complaint narrative', 'Company public response', 'Company',
#        'State', 'ZIP code', 'Tags', 'Consumer consent provided?',
#        'Submitted via', 'Date sent to company', 'Company response to consumer',
#        'Timely response?', 'Consumer disputed?', 'Complaint ID'],
#       dtype='object')

# %%
df = data.iloc[:,[5,7]]
df.columns
df=df.dropna(subset = ['Consumer complaint narrative'])
df
# Out:
#                              Consumer complaint narrative  \
# 1       I have outdated information on my credit repor...
# 2       I purchased a new car on XXXX XXXX. The car de...
# 7       An account on my credit report has a mistaken ...
# 12      This company refuses to provide me verificatio...
# 16      This complaint is in regards to Square Two Fin...
# 25      Started the refinance of home mortgage process...
# 26      In XXXX, I and my ex-husband applied for a ref...
# 28      I have disputed several accounts on my credit ...
# 29      Mortgage was transferred to Nationstar as of X...
# 36      Was a happy XXXX card member for years, in lat...
# 43      Without provocation, I received notice that my...
# 49      I am writing to request your assistance in loo...
# 61      I am disputing the inaccurate information the ...
# 64      Checked my credit report after filing complain...
# 69      Need to move into a XXXX facility. Can no long...
# 80      I attempted to open a XXXX XXXX account on XXX...
# 83      Experian allowed XXXX to pull a hard credit in...
# 85      I had an FHA loan at US Bank that was paid off...
# 90      i was tolled i would have a credit score of XX...
# 95      I went through a divorce several years ago and...
# 98      Signed up for the American Express XXXX Card w...
# 99      RE : Credit Inquiries Experian Credit Report T...
# 103     Experian is reporting an address that is not m...
# 107     My identity was stolen. I filed a complaint, p...
# 118     Select Portfolio Servicing has been deceptive ...
# 124     I have documentation that shows that US Bank w...
# 136     After 2 years of service with no issues Coinba...
# 152     I was dropped from my income based repayment p...
# 153     This complaint is regarding Wells Fargo. XX/XX...
# 154     I received dental procedures and the office ma...
# ...                                                   ...
# 891273  XXXX and XXXX, Wife and Husband, true and lawf...
# 891278  Consumer Portfolio Services called my office a...
# 891280  I left the country on XXXX of XXXX but before ...
# 891283  XX/XX/XXXX, my wife XXXX XXXX XXXX needed mone...
# 891284  Construction Loan Company ( Greensky ) release...
# 891285  HAMP Modification loan has been permanently mo...
# 891294  I have been actively filing loan modifications...
# 891296  I was looking into charges on my credit report...
# 891300  In late XXXX, I applied for a membership in Na...
# 891301  I did not received the proper information on t...
# 891304  I requested a refund from Citibank in XXXX 201...
# 891305  DISCOVER CARD PUT NEGATIVE REMARK " CLOSED BY ...
# 891306  We purchased a ring at Zales on XX/XX/XXXX. Th...
# 891309  TLA, XXXX XXXX, XXXX MD XXXX, XXXX sent out a ...
# 891312  Recent flood insurance claim check was written...
# 891314  Procollect calls me all the time. They must ha...
# 891316  After speaking with CFPB supervisor XXXX XXXX ...
# 891322  The 3rd party first kept calling me without me...
# 891323  Equifax is reporting and inaccurate XXXX XXXX ...
# 891329  I do not owe this company. I have never receiv...
# 891334  ECSI XXXX., based in XXXX, PA, services my XXX...
# 891336  I have a mortgage with Caliber Home Loans ( Ac...
# 891340  My credit report is being negatively affected ...
# 891342  I have never had XXXX billing, and do not owe ...
# 891350  Barclay closed my Barclay XXXX MasterCard acco...
# 891352  Our son was taken to XXXX XXXX XXXX XXXX XXXX ...
# 891353  On XXXX/XXXX/13, without my authorization, Ban...
# 891356  I had an account with XXXX in XX/XX/XXXX this ...
# 891357  I was contacted on XX/XX/XXXX email by XXXX fr...
# 891359  I had a debit that was included in my chapter ...
#
#                                                   Company
# 1                  TRANSUNION INTERMEDIATE HOLDINGS, INC.
# 2                          CITIZENS FINANCIAL GROUP, INC.
# 7                     Experian Information Solutions Inc.
# 12                                    The CBE Group, Inc.
# 16                        SQUARETWO FINANCIAL CORPORATION
# 25                         AMERICAN NEIGHBORHOOD MORTGAGE
# 26                       HSBC NORTH AMERICA HOLDINGS INC.
# 28                                          EQUIFAX, INC.
# 29                                    NATIONSTAR MORTGAGE
# 36                                 BARCLAYS BANK DELAWARE
# 43                                         CITIBANK, N.A.
# 49                                 Selip & Stylianou, LLP
# 61      Fidelity National Information Services, Inc. (...
# 64                    Experian Information Solutions Inc.
# 69                     VANDERBILT MORTGAGE & FINANCE, INC
# 80                            EARLY WARNING SERVICES, LLC
# 83                    Experian Information Solutions Inc.
# 85                                           U.S. BANCORP
# 90                                       Park View Credit
# 95                  BANK OF AMERICA, NATIONAL ASSOCIATION
# 98                               AMERICAN EXPRESS COMPANY
# 99                    Experian Information Solutions Inc.
# 103                   Experian Information Solutions Inc.
# 107                        Southwest Credit Systems, L.P.
# 118                      SELECT PORTFOLIO SERVICING, INC.
# 124                                          U.S. BANCORP
# 136                                        Coinbase, Inc.
# 152                                             AES/PHEAA
# 153                                 WELLS FARGO & COMPANY
# 154                                   SYNCHRONY FINANCIAL
# ...                                                   ...
# 891273              BANK OF AMERICA, NATIONAL ASSOCIATION
# 891278                  CONSUMER PORTFOLIO SERVICES, INC.
# 891280                                 EOS Holdings, Inc.
# 891283                                     CASHCALL, INC.
# 891284                         GreenSky Trade Credit, LLC
# 891285                               JPMORGAN CHASE & CO.
# 891294              BANK OF AMERICA, NATIONAL ASSOCIATION
# 891296                                                ERC
# 891300                          NAVY FEDERAL CREDIT UNION
# 891301                       National Credit Systems,Inc.
# 891304                                     CITIBANK, N.A.
# 891305                                      DISCOVER BANK
# 891306                                     CITIBANK, N.A.
# 891309                                  Pipeline Ventures
# 891312                          NAVY FEDERAL CREDIT UNION
# 891314                                    ProCollect, Inc
# 891316              BANK OF AMERICA, NATIONAL ASSOCIATION
# 891322                  PORTFOLIO RECOVERY ASSOCIATES INC
# 891323                                      EQUIFAX, INC.
# 891329                                 Carter-Young, Inc.
# 891334                      HEARTLAND PAYMENT SYSTEMS INC
# 891336                           Caliber Home Loans, Inc.
# 891340                                   BB&T CORPORATION
# 891342                                                ERC
# 891350                             BARCLAYS BANK DELAWARE
# 891352                      R & B Corporation of Virginia
# 891353              BANK OF AMERICA, NATIONAL ASSOCIATION
# 891356                                                ERC
# 891357                           Caliber Home Loans, Inc.
# 891359                           Midwest Recovery Systems
#
# [191629 rows x 2 columns]

# %%
# Grouping Complaints by Company

all_companies = set(df['Company'])

com_comp = {}
for index, company, complaint in df.itertuples():
    if com_comp.get(company):
        com_comp[company].add(complaint)
    else:
        com_comp[company] = set()
        com_comp[company].add(complaint)

print(len(com_comp))
# Out:
# 187520

# %%
# Simple string operations to merge into one long complaint list per company

extracted = pd.DataFrame()
extracted['complaints'] = com_comp.keys()
extracted['company'] = ['\n'.join(value) for value in com_comp.values()]

# %%
# words concatenated to form one long string 

complaint_set={}
count=0
for c in set(extracted['company']):
    temp=extracted[extracted['company']==c]['complaints']
    ts=""
    for t in temp:
        ts+=str(t)
    
    complaint_set[c]=ts

    count+=1
print("done")

# %%
full_complaint_set = complaint_set
c_set = {}
count=0
for k, v in complaint_set.items():
    c_set[k]=v

# %%
# use gensim to make TaggedDocuments
from gensim.models.doc2vec import TaggedDocument
tagged_docs=[]

for k,v in complaint_set.items():
    td = TaggedDocument(gensim.utils.to_unicode(complaint_set[k]).split(), k)
    tagged_docs.append(td)
print("done")
# Out:
# done

# %%
# Just printing last tagged document to verify
print(td)
# Out:
# TaggedDocument(['rec', 'in', 'the', 'mail', 'offer', '6.29', 'apr,', 'if', 'approved,', 'was', 'approve', 'but', 'came', 'back', '11.5', 'apr', 'their', 'adv', 'is', 'misleading'], OpenRoad Lending)

# %%
model = gensim.models.Doc2Vec(tagged_docs, dm = 0, alpha=0.2, size= 20, min_alpha=0.050, min_count=0, workers=2)
print("creatd")
# Out:
# creatd

# %%
# start training

for epoch in range(100):
    if epoch % 10 == 0:
        print ('Now training epoch %s'%epoch)
    model.train(tagged_docs, total_examples=model.corpus_count, epochs=model.iter)
    model.alpha -= 0.2  # decrease the learning rate
    model.min_alpha = model.alpha  # fix the learning rate, no decay
 
print("All done")
# Out:
# Now training epoch 0
# Now training epoch 10
# Now training epoch 20
# Now training epoch 30
# Now training epoch 40
# Now training epoch 50
# Now training epoch 60
# Now training epoch 70
# Now training epoch 80
# Now training epoch 90
# All done

# %%
# Try clustering with NLTK

import nltk
from gensim.models import Doc2Vec
from nltk.cluster import KMeansClusterer
from nltk.corpus import stopwords
import re

# %%
def preprocess(str):
    # remove links
    str = re.sub(r'http(s)?:\/\/\S*? ', "", str)
    return str

# %%
def preprocess_document(text):
    text = preprocess(text)
    return ''.join([x if x.isalnum() or x.isspace() else " " for x in text ]).split()

# %%
vectors = []
used_objects = []
for k,v in complaint_set.items():
    vectors.append(model.infer_vector(preprocess_document(v)))
    used_objects.append(k)
#vectors

# %%
# K-means clustering
NUM_CLUSTERS=19

kclusterer = KMeansClusterer(NUM_CLUSTERS, distance=nltk.cluster.util.cosine_distance, repeats=25)
assigned_clusters = kclusterer.cluster(vectors, assign_clusters=True)
print("done")
# Out:
# done

# %%
assigned_clusters[0:10]
# Out:
# [16, 2, 2, 10, 9, 18, 15, 13, 11, 11]

# %%
def get_objects_by_cluster(id):
    list = []
    for x in range(0, len(assigned_clusters)):
        if (assigned_clusters[x] == id):
            list.append(used_objects[x])
    return list

# %%
f=open("Clusters.txt","w+")
for i in range(NUM_CLUSTERS):
    objects = get_objects_by_cluster(i)
    print("Cluster ",i, " ",len(objects))
    f.write("Cluster "+ str(i)+"\n\n")
    f.write("Companies - "+ str(objects)+"\n\n")
    for o in objects:
        f.write(complaint_set[o]+"\n\n---\n\n")
    f.write("================================================\n\n")
f.close()
# Out:
# Cluster  0   60
# Cluster  1   36
# Cluster  2   179
# Cluster  3   117
# Cluster  4   51
# Cluster  5   28
# Cluster  6   68
# Cluster  7   19
# Cluster  8   68
# Cluster  9   60
# Cluster  10   73
# Cluster  11   131
# Cluster  12   75
# Cluster  13   116
# Cluster  14   68
# Cluster  15   12
# Cluster  16   121
# Cluster  17   52
# Cluster  18   77
